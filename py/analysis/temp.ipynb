# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../score_board.csv')

# %%
df
# Out:
#             Time        Team Operation  BuyVolume  SellVolume  EtfPosition  \
# 0       0.000021      retard      Tick          0           0            0
# 1       0.000021  LiquidBear      Tick          0           0            0
# 2       0.252391      retard      Tick          0           0            0
# 3       0.252391  LiquidBear      Tick          0           0            0
# 4       0.502664      retard      Tick          0           0            0
# ...          ...         ...       ...        ...         ...          ...
# 7199  899.545414  LiquidBear      Tick       2024        2119          -95
# 7200  899.716111      retard      Tick       5917        5954          -37
# 7201  899.716111  LiquidBear      Tick       2024        2119          -95
# 7202  900.007750      retard      Tick       5917        5954          -37
# 7203  900.007750  LiquidBear      Tick       2024        2119          -95
#
# ...
