# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Begin By Testing on Different Market Datat

# %% [markdown]
# # Market Data 1

# %%
fig = plt.figure(figsize=(15, 6), dpi=80)

#PnL given no realizing PnL
df = pd.read_csv('./../score_board.csv', sep=',')
model = df[df['Team'] == 'BaseModel1']
PnL = [i/100 for i in model['ProfitOrLoss']]

plt.subplot(1, 2, 1)
plt.title('Profit Over Time of Simulation')
plt.xlabel('Time')
plt.ylabel('Profit')
plt.plot(range(len(PnL)), PnL)
# ------------------------------------------------------------------ #
# etf price of the thang we traded
etf_price_of_simulation = [i/100 for i in df['EtfPrice']]

plt.subplot(1, 2, 2)
plt.title('Etf Price of Stock We Just Traded')
plt.xlabel('Time')
plt.ylabel('Price')
plt.plot(range(len(etf_price_of_simulation)), etf_price_of_simulation)

# check Sharpe ratio
temp = list(df['ProfitOrLoss'])
print(f'SHARPE RATIO IS {np.mean(temp) / np.std(temp)}')
# Out:
# SHARPE RATIO IS 1.6909864217833748

# %%
df = pd.read_csv('./../data/fill_ratios.csv', sep=', ', header = None, names = None)
df
# Out:
# /var/folders/g9/5q77t2zj0pxfm_kg1z1df_c80000gn/T/ipykernel_57931/3744289422.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv('./../data/fill_ratios.csv', sep=', ', header = None, names = None)
#             0        1
# 0    0.000000  0.03840
# 1    0.040000  0.03840
# 2    0.029600  0.03840
# 3    0.029600  0.03920
# 4    0.030933  0.03920
# ..        ...      ...
# 168  0.026960  0.03152
# 169  0.027120  0.03152
# 170  0.027120  0.03152
# 171  0.027120  0.03152
# 172  0.027120  0.02960
#
# [173 rows x 2 columns]

# %% [markdown]
# # Market Data 2

# %%
fig = plt.figure(figsize=(15, 6), dpi=80)

#PnL given no realizing PnL
df = pd.read_csv('./../score_board.csv', sep=',')
model = df[df['Team'] == 'BaseModel1']
PnL = [i/100 for i in model['ProfitOrLoss']]

plt.subplot(1, 2, 1)
plt.title('Profit Over Time of Simulation')
plt.xlabel('Time')
plt.ylabel('Profit')
plt.plot(range(len(PnL)), PnL)
# ------------------------------------------------------------------ #
# etf price of the thang we traded
etf_price_of_simulation = [i/100 for i in df['EtfPrice']]

plt.subplot(1, 2, 2)
plt.title('Etf Price of Stock We Just Traded')
plt.xlabel('Time')
plt.ylabel('Price')
plt.plot(range(len(etf_price_of_simulation)), etf_price_of_simulation)

# %% [markdown]
# # Market Data 3

# %%
fig = plt.figure(figsize=(15, 6), dpi=80)

#PnL given no realizing PnL
df = pd.read_csv('./../score_board.csv', sep=',')
model = df[df['Team'] == 'BaseModel1']
PnL = [i/100 for i in model['ProfitOrLoss']]

plt.subplot(1, 2, 1)
plt.title('Profit Over Time of Simulation')
plt.xlabel('Time')
plt.ylabel('Profit')
plt.plot(range(len(PnL)), PnL)
# ------------------------------------------------------------------ #
# etf price of the thang we traded
etf_price_of_simulation = [i/100 for i in df['EtfPrice']]

plt.subplot(1, 2, 2)
plt.title('Etf Price of Stock We Just Traded')
plt.xlabel('Time')
plt.ylabel('Price')
plt.plot(range(len(etf_price_of_simulation)), etf_price_of_simulation)

# %% [markdown]
# # Market Data 4

# %%
fig = plt.figure(figsize=(15, 6), dpi=80)

#PnL given no realizing PnL
df = pd.read_csv('./../score_board.csv', sep=',')
model = df[df['Team'] == 'BaseModel1']
PnL = [i/100 for i in model['ProfitOrLoss']]

plt.subplot(1, 2, 1)
plt.title('Profit Over Time of Simulation')
plt.xlabel('Time')
plt.ylabel('Profit')
plt.plot(range(len(PnL)), PnL)
# ------------------------------------------------------------------ #
# etf price of the thang we traded
etf_price_of_simulation = [i/100 for i in df['EtfPrice']]

plt.subplot(1, 2, 2)
plt.title('Etf Price of Stock We Just Traded')
plt.xlabel('Time')
plt.ylabel('Price')
plt.plot(range(len(etf_price_of_simulation)), etf_price_of_simulation)

# %% [markdown]
# # Testing Different Models

# %%
max(df[df['Team'] == 'LiquidBears_2185']['ProfitOrLoss'])
# Out:
# 461237

# %%
fig = plt.figure(figsize=(15, 6), dpi=80)

#PnL given no realizing PnL
df = pd.read_csv('./../round2/match125_score_board.csv', sep=',')
models = dict()

for name in set(df['Team']):
    models[name] = df[df['Team'] == name]

for name, model in models.items():
    print(name)
    PnL = [i/100 for i in model['ProfitOrLoss']]
    plt.subplot(1, 1, 1)
    plt.title('Profit Over Time of Simulation')
    plt.xlabel('Time')
    plt.ylabel('Profit')
    plt.plot(range(len(PnL)), PnL)
# Out:
# TeamGaveston_51453
# Blacklisted_122333
# CharterAvenue_120519
# RogerGo_68
# JulyWind_210731
# CSEGoons_46
# Yumpy_24
# LiquidBears_2185

# %%
temp = models['LiquidBears_2185']['EtfPrice']
plt.plot(range(len(temp)), temp)

# %%
# comparing Sharpe Ratio of models we ran within the simulation.
sharpe_ratios = dict()

match = pd.read_csv('./../round2/match125_score_board.csv', sep=',')

for model_name in set(df['Team']):
    temp = list(match[match['Team'] == model_name]['ProfitOrLoss'])
    sharpe_ratios[model_name] = (np.mean(temp) / np.std(temp))
    
for one, two in sharpe_ratios.items():
    print(one, ': ', two, sep ='', end='\n')
# Out:
# TeamGaveston_51453: -1.0061574905799708
# Blacklisted_122333: -1.9248852747056007
# CharterAvenue_120519: 3.121330948473187
# RogerGo_68: nan
# JulyWind_210731: -1.780563831480968
# CSEGoons_46: 2.6682171516556505
# Yumpy_24: -0.6611230509563794
# LiquidBears_2185: 1.6274604038935718
# /var/folders/g9/5q77t2zj0pxfm_kg1z1df_c80000gn/T/ipykernel_57931/3442133185.py:8: RuntimeWarning: invalid value encountered in scalar divide
#   sharpe_ratios[model_name] = (np.mean(temp) / np.std(temp))

# %%
fig = plt.figure(figsize=(15, 6), dpi=80)

#PnL given no realizing PnL
df = pd.read_csv('./../../../Downloads/cppready_trader_go/score_board.csv', sep=',')
model = df[df['Team'] == 'C++UntunedButFastModel']
PnL = [i/100 for i in model['ProfitOrLoss']]

plt.subplot(1, 2, 1)
plt.title('Profit Over Time of Simulation')
plt.xlabel('Time')
plt.ylabel('Profit')
plt.plot(range(len(PnL)), PnL)
# ------------------------------------------------------------------ #
# etf price of the thang we traded
etf_price_of_simulation = [i/100 for i in df['EtfPrice']]

plt.subplot(1, 2, 2)
plt.title('Etf Price of Stock We Just Traded')
plt.xlabel('Time')
plt.ylabel('Price')
plt.plot(range(len(etf_price_of_simulation)), etf_price_of_simulation)
